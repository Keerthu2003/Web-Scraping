# %%
pip install bs4
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
import requests

# %%
url="https://www.flipkart.com/kitchen-cookware-serveware/lunch-boxes-bottles-and-flasks/water-bottles/pr?sid=upp%2Cf2k%2C0zz&ctx=...%3D%3D&fm=neo%2Fmerchandising&iid=M_809f64d1-961b-42d2-8ce1-3df1e8113480_4.7358ZVVRS9DZ&ppt=None&ppn=None&ssid=yo27gu0duo0000001680343144768&otracker=hp_omu_Top%2BOffers_6_4.dealCard.OMU_7358ZVVRS9DZ_3&otracker1=hp_omu_PINNED_neo%2Fmerchandising_Top%2BOffers_NA_dealCard_cc_6_NA_view-all_3&cid=7358ZVVRS9DZ"

# %%
permission=requests.get(url)

# %%
permission
# Out:
# <Response [200]>

# %%
from bs4 import BeautifulSoup

# %%
TEXT_HTML=BeautifulSoup(permission.text)

# %%
import pandas as keerthu

# %%
brand=TEXT_HTML.select(".s1Q9rs")

# %%
price=TEXT_HTML.select('._8VNy32 ._30jeq3')

# %%
price
# Out:
# [<div class="_30jeq3">₹404</div>,
#  <div class="_30jeq3">₹429</div>,
#  <div class="_30jeq3">₹249</div>,
#  <div class="_30jeq3">₹349</div>,
#  <div class="_30jeq3">₹299</div>,
#  <div class="_30jeq3">₹495</div>,
#  <div class="_30jeq3">₹499</div>,
#  <div class="_30jeq3">₹320</div>,
#  <div class="_30jeq3">₹297</div>,
#  <div class="_30jeq3">₹377</div>,
#  <div class="_30jeq3">₹399</div>,
#  <div class="_30jeq3">₹429</div>,
#  <div class="_30jeq3">₹799</div>,
#  <div class="_30jeq3">₹449</div>,
#  <div class="_30jeq3">₹299</div>,
#  <div class="_30jeq3">₹449</div>,
#  <div class="_30jeq3">₹199</div>,
#  <div class="_30jeq3">₹299</div>,
#  <div class="_30jeq3">₹199</div>,
#  <div class="_30jeq3">₹649</div>,
#  <div class="_30jeq3">₹247</div>,
#  <div class="_30jeq3">₹499</div>,
#  <div class="_30jeq3">₹519</div>,
#  <div class="_30jeq3">₹715</div>,
#  <div class="_30jeq3">₹499</div>,
#  <div class="_30jeq3">₹304</div>,
#  <div class="_30jeq3">₹399</div>,
# ...

# %%
table=keerthu.DataFrame(brand,columns=['Brand'])

# %%
table
# Out:
#                                                 Brand
# 0   NORVIUM Drinking Water Bottles For Fridge Home...
# 1   WineBIrd Transparent Gold Line P06 1000 ml Bottle
# 2   Flipkart SmartBuy Designer Mosaic Bottle - 100...
# 3   AneriDEALS Crystal Clear Water Bottle for Frid...
# 4   Kimaya Stainless Steel water bottle 1000 ml Bo...
# 5                       Mastercool ECO 1000 ml Bottle
# 6   The Better Home 1000 Stainless Steel Bottle 1 ...
# 7   Savorier Quality Square Shape Fridge Bottle 10...
# 8   aaryashoppy Unbreakable Silicone Water Bottle ...
# 9   SPEEDEX Stainless Steel Water Bottle for fridg...
# 10               cello Venice Set of 5 1000 ml Bottle
# 11  WineBIrd Round Printed Design 6PCS Premium Wat...
# 12            MILTON COPPER CHARGE 1000 930 ml Bottle
# 13  iVBOX ®BOOSTER Hot & Cold Steel Double-Wall Va...
# 14  Rani enterprise High quality stainless steel 1...
# 15  NIRLON Copper Tamba Bottle with Leaf Proof Pro...
# ...

# %%
table2=keerthu.DataFrame(brand,columns=['Brand'])

# %%
table=keerthu.DataFrame(price,columns=['price'])

# %%
table2["Price"]=table

# %%
des=TEXT_HTML.select('._3Djpdu')

# %%
table2["Description"]=des

# %%
table2
# Out:
#                                                 Brand   Price  \
# 0   NORVIUM Drinking Water Bottles For Fridge Home...    ₹404
# 1   WineBIrd Transparent Gold Line P06 1000 ml Bottle    ₹429
# 2   Flipkart SmartBuy Designer Mosaic Bottle - 100...    ₹249
# 3   AneriDEALS Crystal Clear Water Bottle for Frid...    ₹349
# 4   Kimaya Stainless Steel water bottle 1000 ml Bo...    ₹299
# 5                       Mastercool ECO 1000 ml Bottle    ₹495
# 6   The Better Home 1000 Stainless Steel Bottle 1 ...    ₹499
# 7   Savorier Quality Square Shape Fridge Bottle 10...    ₹320
# 8   aaryashoppy Unbreakable Silicone Water Bottle ...    ₹297
# 9   SPEEDEX Stainless Steel Water Bottle for fridg...    ₹377
# 10               cello Venice Set of 5 1000 ml Bottle    ₹399
# 11  WineBIrd Round Printed Design 6PCS Premium Wat...    ₹429
# 12            MILTON COPPER CHARGE 1000 930 ml Bottle    ₹799
# 13  iVBOX ®BOOSTER Hot & Cold Steel Double-Wall Va...    ₹449
# ...
